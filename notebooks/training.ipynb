# %%
# !export HF_ENABLE_PARALLEL_LOADING=true
# !export HF_PARALLEL_LOADING_WORKERS=8

# !export RUN_NAME_FULL=qwen2_5_vl_lora_full_$(date +%Y%m%d_%H%M%S) && export OUT_DIR_FULL=checkpoints/$RUN_NAME_FULL

# %% [markdown]
# # export bash values
# `
# export RUN_NAME=qwen2_5_vl_lora_run_$(date +%Y%m%d_%H%M%S)
# export OUT_DIR=checkpoints/$RUN_NAME
# echo "$OUT_DIR"
# `
#
# # smoke test
# `
# export HF_HOME=~/llm_train/.hf_home
# export HF_ENABLE_PARALLEL_LOADING=true
# export HF_PARALLEL_LOADING_WORKERS=8
#
# python train_qwen_vl_lora_qlora.py
# --model_id Qwen/Qwen2.5-VL-7B-Instruct
# --profile nrp_a100_32gb
# --data_file train.jsonl
# --eval_data_file eval.jsonl
# --output_dir "$OUT_DIR"
# --num_epochs 1
# --max_samples 100
# --evaluation_strategy epoch
# --save_steps 50
# --logging_steps 10
#   `
#
# # full training
# `
# export RUN_NAME_FULL=qwen2_5_vl_lora_full_$(date +%Y%m%d_%H%M%S)
# export OUT_DIR_FULL=checkpoints/$RUN_NAME_FULL
#
# nohup env \
#   HF_HOME=~/llm_train/.hf_home \
#   HF_ENABLE_PARALLEL_LOADING=true \
#   HF_PARALLEL_LOADING_WORKERS=8 \
#   PYTHONUNBUFFERED=1 \
#   python train_qwen_vl_lora_qlora.py \
#   --model_id Qwen/Qwen2.5-VL-7B-Instruct \
#   --profile nrp_a100_32gb \
#   --data_file input/512/train.jsonl \
#   --eval_data_file input/512/eval.jsonl \
#   --output_dir "$OUT_DIR_FULL" \
#   --evaluation_strategy epoch \
#   --load_best_model_at_end \
#   --early_stopping_patience 3 > train_full.log 2>&1 &
#   `
